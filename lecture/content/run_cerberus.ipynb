# %% [markdown]
# # Modular example run

# %%
from cerberus.objects import GeneticInteractionSample

# %%
gi_obj = GeneticInteractionSample(
    cell_line='RPE1',
    reco_table_file='',
    query_casette={},
    other_casette={},
    t0_tend_reco_mapping={},
    dataset_name='Core essentialome',
    tend_reco_rep_pairs=[[]],
    neutral_control_gene='NHT',
    conditions={},
    bio_reps={}, 
    tech_reps={},
    guide_reps={},
    orientation_reps=False,
    guide_combination={},
    merge_orientations=False,
    genes_to_remove=[],
    custom_ess=[],
    custom_noness=[],
    custom_enh_prolif=[],
    output_folder='',
    low_reco_cutoff=10,
    main_effects='overall',
    merge_casettes=False,
    sampling=False,
    n_sample=10,
    n_bins=8,
    min_points=30,
    frac=0.666,
    degree=1,
    plot_fit=False,
    force_ma_transform=False,
    loess_sc_remove=0,
    medpol_sc_remove=0,
    max_iterations=100,
    tol=1e-6,
    force_results=False,
    scaling='No Scaling',
    adjust_gis=True,
    lower_quant=10,
    upper_quant=90,
    opt_exclusion=1,
    store_raw_gi_scores=False
)
